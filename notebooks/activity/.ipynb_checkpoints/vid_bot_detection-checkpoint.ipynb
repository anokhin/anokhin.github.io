# %%
import numpy as np
import pandas as pd

import pylab as pl
import seaborn as sns

# %pylab inline

import sklearn.decomposition as sd
import sklearn.manifold as sm
import sklearn.cluster as sc

import operator
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_activity = pd.read_csv(
    '/Users/anokhin/Desktop/activities.tsv', 
    sep='\t', 
    header=None,
    index_col=0,
    names=[
        "vid",
        "n_sessions",
        "n_hits",
        "n_days",
        "hits_per_session_mean",
        "hits_per_session_std",
        "domains_per_session_mean",
        "domains_per_session_std",
        "interval_between_hits_mean",
        "interval_between_hits_std",
        "len_of_session_mean",
        "len_of_session_std",
        "interval_between_sessions_mean",
        "interval_between_sessions_std",
        "sessions_per_day_mean",
        "sessions_per_day_std"
    ]
)
df_activity.describe()
# Out:
#            n_sessions          n_hits          n_days  hits_per_session_mean  \
# count  1000000.000000  1000000.000000  1000000.000000         1000000.000000
# mean         7.300541       83.238888        2.942064               7.088886
# std         14.927863      367.438099        3.332657              24.051601
# min          1.000000        1.000000        1.000000               1.000000
# 25%          1.000000        2.000000        1.000000               1.318000
# 50%          1.000000        6.000000        1.000000               3.000000
# 75%          5.000000       31.000000        3.000000               7.300000
# max        335.000000    62665.000000       20.000000           10436.000000
#
#        hits_per_session_std  domains_per_session_mean  \
# count        1000000.000000            1000000.000000
# mean               4.350009                  1.572972
# std               20.751795                  2.664021
# min                0.000000                  1.000000
# 25%                0.000000                  1.000000
# 50%                0.000000                  1.000000
# 75%                3.527250                  1.714000
# max            11038.809000               2168.000000
#
#        domains_per_session_std  interval_between_hits_mean  \
# count           1000000.000000               763672.000000
# mean                  0.389670                   94.523183
# std                   1.045537                  119.499527
# min                   0.000000                    0.000000
# 25%                   0.000000                   28.000000
# 50%                   0.000000                   57.908000
# 75%                   0.354000                  109.600000
# max                 222.254000                 1200.000000
#
#        interval_between_hits_std  len_of_session_mean  len_of_session_std  \
# count              763672.000000       1000000.000000      1000000.000000
# mean                  106.557211           362.064832          287.124925
# std                   109.932266           688.444898          608.518814
# min                     0.000000             0.000000            0.000000
# 25%                    15.091500             2.000000            0.000000
# 50%                    78.489000           133.000000            0.000000
# 75%                   163.937000           466.000000          387.550000
# max                   844.993000         77796.182000        44382.132000
#
#        interval_between_sessions_mean  interval_between_sessions_std  \
# count                   492268.000000                  492268.000000
# mean                    170922.597185                  115981.856871
# std                     225469.795449                  144926.166549
# min                       1201.000000                       0.000000
# 25%                      34901.099750                     958.843750
# 50%                      92670.900000                   73723.363000
# 75%                     203169.300000                  156223.271250
# max                    1640193.000000                 1150876.390000
#
#        sessions_per_day_mean  sessions_per_day_std
# count         1000000.000000        1000000.000000
# mean                1.629503              0.456776
# std                 1.258871              0.901928
# min                 0.500000              0.000000
# 25%                 1.000000              0.000000
# 50%                 1.000000              0.000000
# 75%                 1.889000              0.577000
# max                28.000000             14.130000

# %%
n_columns = len(df_activity.columns)

fig = pl.figure(figsize=(5, 5 * n_columns))

for i, col_i in enumerate(df_activity.columns):   
    ax = pl.subplot(n_columns, 1, i + 1)
    
    c = df_activity[col_i]    
    sns.distplot(np.log1p(c[~np.isnan(c)]), kde=False, bins=50)    

pl.show()

# %%
df_activity_sample = df_activity.sample(10000)
df_activity_sample_log = np.log1p(df_activity_sample)
df_activity_sample_log_norm = (df_activity_sample - df_activity_sample.mean()) / df_activity_sample.std()
df_activity_sample_log_norm.fillna(0, inplace=True)
df_activity_sample_log_norm.describe()
# Out:
#          n_sessions        n_hits        n_days  hits_per_session_mean  \
# count  1.000000e+04  1.000000e+04  1.000000e+04           1.000000e+04
# mean   8.526513e-18 -1.474376e-17  5.258016e-17           4.440892e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00           1.000000e+00
# min   -4.255194e-01 -2.346966e-01 -5.869629e-01          -3.428353e-01
# 25%   -4.255194e-01 -2.319457e-01 -5.869629e-01          -3.283623e-01
# 50%   -4.255194e-01 -2.209423e-01 -5.869629e-01          -2.327748e-01
# 75%   -9.274961e-02 -1.521710e-01  3.082070e-01           5.671190e-03
# max    1.068899e+01  3.591699e+01  5.082446e+00           4.973467e+01
#
#        hits_per_session_std  domains_per_session_mean  \
# count          1.000000e+04              1.000000e+04
# mean           1.182343e-15             -4.945377e-16
# std            1.000000e+00              1.000000e+00
# min           -3.398431e-01             -2.124947e-01
# 25%           -3.398431e-01             -2.124947e-01
# 50%           -3.398431e-01             -2.124947e-01
# 75%           -7.667363e-02              4.671204e-02
# max            2.555799e+01              8.741172e+01
#
#        domains_per_session_std  interval_between_hits_mean  \
# count             1.000000e+04                1.000000e+04
# mean             -2.099654e-15                1.059419e-15
# std               1.000000e+00                8.729698e-01
# min              -4.134145e-01               -7.766451e-01
# 25%              -4.134145e-01               -4.805150e-01
# 50%              -4.134145e-01               -9.113039e-02
# 75%              -2.917641e-02                0.000000e+00
# max               1.435052e+01                8.942975e+00
#
#        interval_between_hits_std  len_of_session_mean  len_of_session_std  \
# count               1.000000e+04         1.000000e+04        1.000000e+04
# mean               -1.682565e-15        -4.092726e-16       -8.711254e-16
# std                 8.729698e-01         1.000000e+00        1.000000e+00
# min                -9.601475e-01        -5.714681e-01       -4.962432e-01
# 25%                -7.051656e-01        -5.683079e-01       -4.962432e-01
# 50%                 0.000000e+00        -3.660573e-01       -4.962432e-01
# 75%                 2.566897e-01         1.616904e-01        1.758736e-01
# max                 6.535205e+00         2.212695e+01        2.015473e+01
#
#        interval_between_sessions_mean  interval_between_sessions_std  \
# count                    1.000000e+04                   1.000000e+04
# mean                    -3.808509e-16                  -4.874323e-16
# std                      7.002493e-01                   7.002493e-01
# min                     -7.534486e-01                  -8.148145e-01
# 25%                     -3.387629e-01                  -2.719980e-01
# 50%                      0.000000e+00                   0.000000e+00
# 75%                      0.000000e+00                   0.000000e+00
# max                      6.591951e+00                   6.781992e+00
#
#        sessions_per_day_mean  sessions_per_day_std
# count           1.000000e+04          1.000000e+04
# mean           -2.495426e-15         -2.932410e-15
# std             1.000000e+00          1.000000e+00
# min            -8.891777e-01         -5.113553e-01
# 25%            -4.983408e-01         -5.113553e-01
# 50%            -4.983408e-01         -5.113553e-01
# 75%             2.122009e-01          1.351300e-01
# max             1.122677e+01          9.176960e+00

# %%
pca = sd.PCA(n_components=None)
X = pca.fit_transform(df_activity_sample_log_norm.values)
print "Explained variance: \n " + "\n ".join([str(v * 100) for v in pca.explained_variance_ratio_.cumsum()])
Y = X[:, :]
# Out:
# Explained variance:
#  39.3264223192
#  54.7600194933
#  63.735923862
#  71.3743068682
#  77.4973616974
#  82.0866343953
#  85.97548647
#  88.7605488392
#  91.2332729658
#  93.628169755
#  95.7898469319
#  97.5265067025
#  98.6907733327
#  99.5591841074
#  100.0

# %%
tsne = sm.TSNE(
    n_components=2, 
    n_iter=1000, 
    perplexity=30, 
    early_exaggeration=10.0, 
    min_grad_norm=1e-10, 
    n_iter_without_progress=100, 
    learning_rate=2000, 
    random_state=42, 
    verbose=2,
#     metric='correlation'    
)
Z = tsne.fit_transform(Y)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Iteration 25: error = 1.2382729, gradient norm = 0.0069642
# [t-SNE] Iteration 50: error = 1.2237848, gradient norm = 0.0038796
# [t-SNE] Iteration 75: error = 1.1620359, gradient norm = 0.0023227
# [t-SNE] Iteration 100: error = 1.1403108, gradient norm = 0.0021788
# [t-SNE] Error after 100 iterations with early exaggeration: 1.140311
# [t-SNE] Iteration 125: error = 1.0905592, gradient norm = 0.0017939
# [t-SNE] Iteration 150: error = 1.0720969, gradient norm = 0.0016884
# [t-SNE] Iteration 175: error = 1.0670447, gradient norm = 0.0017092
# [t-SNE] Iteration 200: error = 1.0656034, gradient norm = 0.0017009
# [t-SNE] Iteration 225: error = 1.0652130, gradient norm = 0.0017001
# [t-SNE] Iteration 250: error = 1.0651282, gradient norm = 0.0016995
# [t-SNE] Iteration 275: error = 1.0650491, gradient norm = 0.0016995
# [t-SNE] Iteration 300: error = 1.0650560, gradient norm = 0.0016988
# [t-SNE] Iteration 325: error = 1.0650662, gradient norm = 0.0016986
# [t-SNE] Iteration 325: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Error after 325 iterations: 1.065066

# %%
dbscan = sc.DBSCAN(eps=0.5, min_samples=5)
cls = dbscan.fit_predict(Z)

# %%
kmeans = sc.KMeans(n_clusters=30, n_init=100, max_iter=1000, verbose=0)
cls = kmeans.fit_predict(X)

# %%
n_clusters = len(np.unique(cls))
print "%d clusters found" % n_clusters
cluster_sizes = sorted([(c, (cls == c).sum()) for c in xrange(n_clusters)], key=operator.itemgetter(1), reverse=True)
# Out:
# 30 clusters found

# %%
pl.plot(range(n_clusters), np.cumsum(map(lambda cs: cs[1], cluster_sizes)), "o-")
pl.show()

# %%
N_TOP_CLUSTERS = 12
top_clusters = map(lambda cs: cs[0], cluster_sizes)[:N_TOP_CLUSTERS]

cm = pl.cm.Paired

pl.figure(figsize=(15, 15))
for c in xrange(n_clusters):    
    pl.scatter(Z[cls == c, 0], Z[cls == c, 1], color=cm(int(1.0 * c / n_clusters * 256)) if c in top_clusters else 'gray', label="%d" % c)
    
pl.legend()
pl.show()

# %%
df_activity_sample_cls = df_activity_sample.copy()
df_activity_sample_cls["cls"] = cls
df_activity_sample_cls.head()
# Out:
#            n_sessions  n_hits  n_days  hits_per_session_mean  \
# vid
# 20780541a           1      16       1                 16.000
# 20d816c73           1       3       1                  3.000
# 1caeb21a2          32     167      10                  5.219
# 26f2d6aeb          51     627      11                 12.294
# 2079de7c5           1       1       1                  1.000
#
#            hits_per_session_std  domains_per_session_mean  \
# vid
# 20780541a                 0.000                     2.000
# 20d816c73                 0.000                     1.000
# 1caeb21a2                 4.877                     1.000
# 26f2d6aeb                 9.894                     1.098
# 2079de7c5                 0.000                     1.000
#
#            domains_per_session_std  interval_between_hits_mean  \
# vid
# 20780541a                    0.000                      29.267
# 20d816c73                    0.000                      23.000
# 1caeb21a2                    0.000                      67.533
# 26f2d6aeb                    0.361                      66.819
# 2079de7c5                    0.000                         NaN
#
#            interval_between_hits_std  len_of_session_mean  len_of_session_std  \
# vid
# 20780541a                     18.851              439.000               0.000
# 20d816c73                      7.071               46.000               0.000
# 1caeb21a2                    156.626              284.906             492.387
# 26f2d6aeb                    155.881              754.667             726.200
# 2079de7c5                        NaN                0.000               0.000
#
#            interval_between_sessions_mean  interval_between_sessions_std  \
# vid
# 20780541a                             NaN                            NaN
# 20d816c73                             NaN                            NaN
# 1caeb21a2                       50696.871                      63254.013
# 26f2d6aeb                       30608.900                      58288.175
# 2079de7c5                             NaN                            NaN
#
#            sessions_per_day_mean  sessions_per_day_std  cls
# vid
# 20780541a                  1.000                 0.000    0
# 20d816c73                  1.000                 0.000    0
# 1caeb21a2                  3.200                 1.398   13
# 26f2d6aeb                  4.636                 3.139   26
# 2079de7c5                  1.000                 0.000   28

# %%
print top_clusters
df_stats = pd.concat([df_activity_sample_cls[df_activity_sample_cls.cls == c].describe().loc[["max"]] for c in top_clusters])
df_stats
# Out:
# [28, 0, 18, 10, 13, 1, 7, 9, 15, 2, 27, 19]
#      n_sessions  n_hits  n_days  hits_per_session_mean  hits_per_session_std  \
# max           5      34       5                 10.000                 9.192
# max           6      78       6                 61.000                18.502
# max          18     256      12                 25.500                28.500
# max           9     114       3                 32.000                23.011
# max          51     798      18                 28.500                27.030
# max          25     162      13                 21.000                18.173
# max           5     126       5                 68.000                26.163
# max          23     431      12                 36.125                45.124
# max           8     236       6                 78.667                46.694
# max          58    1712      20                 46.270                51.900
# max          20      45      11                  9.000                 4.761
# max           4      98       4                 49.000                41.012
#
#      domains_per_session_mean  domains_per_session_std  \
# max                     5.000                    1.732
# max                     6.000                    1.500
# max                     6.636                    2.138
# max                     6.500                    2.309
# max                     3.750                    2.940
# max                     5.000                    2.121
# max                     6.000                    2.121
# max                     6.667                    4.412
# max                     4.500                    2.887
# max                     6.450                    5.373
# max                     4.000                    2.217
# max                     6.500                    2.121
#
#      interval_between_hits_mean  interval_between_hits_std  \
# max                     397.000                    249.890
# max                     157.000                     92.533
# max                     393.000                    209.706
# max                     403.000                    274.780
# max                     474.000                    316.537
# max                     441.000                    415.443
# max                     344.000                    379.062
# max                     230.136                    353.237
# max                     638.000                    391.700
# max                     196.865                    282.693
# max                     717.500                    831.558
# max                     354.000                    434.704
#
#      len_of_session_mean  len_of_session_std  interval_between_sessions_mean  \
# max              650.000             679.530                      524878.000
# max              743.000             605.283                      538774.000
# max             1080.727             965.198                      406045.500
# max             1098.333            1077.201                      156420.000
# max             1491.778            1584.382                      140620.182
# max             1717.000            1578.112                      544835.000
# max             2330.000            1086.823                      522807.000
# max             2336.750            1915.050                      683114.500
# max             1284.000            1920.982                      796866.000
# max             2384.976            2817.778                      112327.214
# max             2490.000            2252.608                     1000755.000
# max             1776.000            2101.521                     1628703.000
#
#      interval_between_sessions_std  sessions_per_day_mean  \
# max                     316268.357                  2.000
# max                     321165.936                  2.000
# max                     403712.314                  4.000
# max                     102711.779                  7.000
# max                     286839.331                  5.125
# max                     502664.946                  5.000
# max                     259045.741                  2.000
# max                     599487.448                  6.000
# max                    1073272.128                  3.500
# max                     296216.418                  7.800
# max                     561870.237                  5.000
# max                     279434.458                  1.000
#
#      sessions_per_day_std  cls
# max                 0.707   28
# max                 0.707    0
# max                 2.887   18
# max                 1.414   10
# max                 3.251   13
# max                 2.309    1
# max                 0.707    7
# max                 2.828    9
# max                 2.121   15
# max                 3.710    2
# max                 2.082   27
# max                 0.000   19

# %%
df_stats_norm = df_stats[features].copy()
df_stats_norm = df_stats_norm / df_stats_norm.max()
df_stats_norm
# Out:
#      n_sessions    n_hits  n_days  hits_per_session_mean  \
# max    0.086207  0.019860    0.25               0.127118
# max    0.103448  0.045561    0.30               0.775420
# max    0.310345  0.149533    0.60               0.324151
# max    0.155172  0.066589    0.15               0.406778
# max    0.879310  0.466121    0.90               0.362287
# max    0.431034  0.094626    0.65               0.266948
# max    0.086207  0.073598    0.25               0.864403
# max    0.396552  0.251752    0.60               0.459214
# max    0.137931  0.137850    0.30               1.000000
# max    1.000000  1.000000    1.00               0.588175
# max    0.344828  0.026285    0.55               0.114406
# max    0.068966  0.057243    0.20               0.622879
#
#      hits_per_session_std  domains_per_session_mean  domains_per_session_std  \
# max              0.177110                  0.749963                 0.322353
# max              0.356493                  0.899955                 0.279174
# max              0.549133                  0.995350                 0.397916
# max              0.443372                  0.974951                 0.429741
# max              0.520809                  0.562472                 0.547180
# max              0.350154                  0.749963                 0.394752
# max              0.504104                  0.899955                 0.394752
# max              0.869441                  1.000000                 0.821143
# max              0.899692                  0.674966                 0.537316
# max              1.000000                  0.967452                 1.000000
# max              0.091734                  0.599970                 0.412619
# max              0.790212                  0.974951                 0.394752
#
#      interval_between_hits_mean  interval_between_hits_std  \
# max                    0.553310                   0.300508
# max                    0.218815                   0.111277
# max                    0.547735                   0.252184
# max                    0.561672                   0.330440
# max                    0.660627                   0.380655
# max                    0.614634                   0.499596
# max                    0.479443                   0.455846
# max                    0.320747                   0.424789
# max                    0.889199                   0.471044
# max                    0.274376                   0.339956
# max                    1.000000                   1.000000
# max                    0.493380                   0.522758
#
#      len_of_session_mean  len_of_session_std  interval_between_sessions_mean  \
# max             0.261044            0.241158                        0.322267
# max             0.298394            0.214809                        0.330799
# max             0.434027            0.342539                        0.249306
# max             0.441098            0.382287                        0.096040
# max             0.599108            0.562281                        0.086339
# max             0.689558            0.560055                        0.334521
# max             0.935743            0.385702                        0.320996
# max             0.938454            0.679631                        0.419422
# max             0.515663            0.681736                        0.489264
# max             0.957822            1.000000                        0.068967
# max             1.000000            0.799427                        0.614449
# max             0.713253            0.745808                        1.000000
#
#      interval_between_sessions_std  sessions_per_day_mean  \
# max                       0.294677               0.256410
# max                       0.299240               0.256410
# max                       0.376151               0.512821
# max                       0.095700               0.897436
# max                       0.267257               0.657051
# max                       0.468348               0.641026
# max                       0.241361               0.256410
# max                       0.558561               0.769231
# max                       1.000000               0.448718
# max                       0.275994               1.000000
# max                       0.523511               0.641026
# max                       0.260358               0.128205
#
#      sessions_per_day_std
# max              0.190566
# max              0.190566
# max              0.778167
# max              0.381132
# max              0.876280
# max              0.622372
# max              0.190566
# max              0.762264
# max              0.571698
# max              1.000000
# max              0.561186
# max              0.000000

# %%
features = [
        "n_sessions", 
        "n_hits", 
        "n_days", 
        "hits_per_session_mean", 
        "hits_per_session_std", 
        "domains_per_session_mean", 
        "domains_per_session_std", 
        "interval_between_hits_mean", 
        "interval_between_hits_std", 
        "len_of_session_mean", 
        "len_of_session_std", 
        "interval_between_sessions_mean", 
        "interval_between_sessions_std", 
        "sessions_per_day_mean", 
        "sessions_per_day_std"
    ]



def radar(centroid, features, axes, color, ymax=1):
    # Set ticks to the number of features (in radians)
    t = np.arange(0, 2*np.pi, 2*np.pi/len(features))
    plt.xticks(t, [])

    # Set yticks from 0 to 1
    plt.yticks([0.5], [])

    # Draw polygon representing centroid
    points = [(x, y) for x, y in zip(t, centroid)]
    points.append(points[0])
    points = np.array(points)
    codes = [path.Path.MOVETO,] + [path.Path.LINETO,] * (len(centroid) - 1) + [ path.Path.CLOSEPOLY ]
    _path = path.Path(points, codes)
    _patch = patches.PathPatch(_path, fill=True, color=color, linewidth=0, alpha=.7)
    axes.add_patch(_patch)
    _patch = patches.PathPatch(_path, fill=False, linewidth = 2)
    axes.add_patch(_patch)

    # Draw circles at value points
    plt.scatter(points[:,0], points[:,1], linewidth=2, s=50, color='white', edgecolor='black', zorder=10)

    # Set axes limits
    plt.ylim(0, ymax)

    # Draw ytick labels to make sure they fit properly
    for i in range(len(features)):
        angle_rad = i/float(len(features))*2*np.pi
        angle_deg = i/float(len(features))*360
        ha = "right"
        if angle_rad < np.pi/2 or angle_rad > 3*np.pi/2: ha = "left"
        plt.text(angle_rad, ymax * 1.05, features[i], size=7, horizontalalignment=ha, verticalalignment="center")

# Some additiola imports
import matplotlib
import matplotlib.path as path
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Choose some nice colors
matplotlib.rc('axes', facecolor = 'lightgray')
# Make figure background the same colors as axes 
fig = plt.figure(figsize=(20, 20), facecolor='white')

cm = pl.cm.Paired

for j, c in enumerate(top_clusters):        
    centroid = df_stats_norm[df_stats.cls == c].values.mean(axis=0)
    # Use a polar axes
    axes = plt.subplot(4, 3, j + 1, polar=True)
    radar(centroid, features, axes, cm(int(1.0 * c / n_clusters * 256)))

plt.show()

# %%
with open("/Users/anokhin/Desktop/vids.txt", "w") as vf:
    for vid in df_activity_sample_cls.index.values:
        print >> vf, vid

# %% [markdown]
# # INDIVIDUAL USERS

# %%
vid_data = {}
with open("/Users/anokhin/Desktop/users.txt", "r") as vf:
    for line in vf:
        vid, data = line.strip().split("\t")
        vid_data[vid] = {}
        
        for d in data.split(","):
            if not d:
                continue
                
            ts = int(d.split(":")[0])
            domain = d.split(":")[1]
            
            if domain not in vid_data[vid]:
                vid_data[vid][domain] = [ts]
            else:
                vid_data[vid][domain].append(ts)       
        
print vid_data.items()[:5]
# Out:
# [('12665cb45', {'m.odnoklassniki.ru': [2933843025, 2933843073, 2933843116, 2933843211, 2933843286, 2933843295, 2933843438, 2933843455]}), ('167a62564', {'m.ok.ru': [2933167282]}), ('20775654b', {'1001goroskop.ru': [2932777605]}), ('32114e796', {'m.ok.ru': [2933167507, 2933428058, 2933428092, 2933428184, 2933428238, 2933428343, 2933428381, 2933428461, 2933428628, 2933428649, 2933428806, 2933428827, 2933429420, 2933429484, 2933429645, 2933648703, 2933654854, 2933654869, 2933655046, 2933655061, 2933655065, 2933655097, 2933655107, 2933655125, 2933655187, 2933655326, 2933655364, 2933655470, 2933655635, 2933655968, 2933656021, 2933656055, 2933656059, 2933656081, 2933656483, 2933656501, 2933656609, 2933665110, 2933665145, 2933665203, 2933665282, 2933665303, 2934119301, 2934119325, 2934119386, 2934119450, 2934119475, 2934119552, 2934119563, 2934120121, 2934120133, 2934120157, 2934120168, 2934120185, 2934120221, 2934120232, 2934152139, 2934152256, 2934152370, 2934152383, 2934152415, 2934152594, 2934152617, 2934152675, 2934152733, 2934152743, 2934152749, 2934152776, 2934152801, 2934337058, 2934337060, 2934337138, 2934337157, 2934352340, 2934352623, 2934352688, 2934352697, 2934354955, 2934355013, 2934355060, 2934355123, 2934355240, 2934355252, 2934355268, 2934355272, 2934355276], 'm.vk.com': [2933166942, 2933166943, 2933167281, 2933167282, 2933167396, 2933167496, 2933167497], 'news.mail.ru': [2934151500, 2934151504], 'touch.auto.mail.ru': [2934152074, 2934152079], 'lady.mail.ru': [2934151866, 2934151869], 'touch.otvet.mail.ru': [2933492664, 2933492665], 'charter97.org': [2934375984, 2934376229, 2934376246, 2934376406], 'mail.ru': [2934151304, 2934151314, 2934151314, 2934151948, 2934151955, 2934151955], 'russian.rt.com': [2933602349]}), ('11831557e', {'www.nov-detsad10.ru': [2934361945, 2934361950, 2934361960, 2934361969, 2934361974, 2934361980, 2934361991, 2934368195, 2934368210, 2934368231], '2detsad.ucoz.ru': [2934362036, 2934367954], 'sadik7.ru': [2934362148, 2934362152, 2934362158, 2934368676, 2934368681]})]

# %%
vid = df_activity_sample_cls[df_activity_sample_cls.cls == 1].sample(1).index[0]

cm=pl.cm.Dark2
for d, ts_list in vid_data[vid]:    
    pl.scatter()
pl.show()
